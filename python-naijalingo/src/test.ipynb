# %%
# !pip install naijalingo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting naijalingo
#   Downloading naijalingo-2.0.6-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\okoli\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from naijalingo) (0.28.1)
# Requirement already satisfied: anyio in c:\users\okoli\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx>=0.25.0->naijalingo) (4.12.1)
# Requirement already satisfied: certifi in c:\users\okoli\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx>=0.25.0->naijalingo) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\okoli\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx>=0.25.0->naijalingo) (1.0.9)
# Requirement already satisfied: idna in c:\users\okoli\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx>=0.25.0->naijalingo) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\okoli\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpcore==1.*->httpx>=0.25.0->naijalingo) (0.16.0)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\okoli\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from anyio->httpx>=0.25.0->naijalingo) (4.15.0)
# Downloading naijalingo-2.0.6-py3-none-any.whl (17 kB)
# Installing collected packages: naijalingo
# Successfully installed naijalingo-2.0.6
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: C:\Users\okoli\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from naijalingo import NaijaLingo

# Point to your local server
from naijalingo import NaijaLingo
API_KEY = "YOUR_API_KEY"  # Replace with your actual API key
client = NaijaLingo(api_key=API_KEY)

# %%
# Test all endpoints
status = client.tts.health()
print("Health:", status.status, f"({status.total_speakers} speakers)")
# Out:
# Health: starting (0 speakers)

# %%
models = client.list_models()
print("Models:", [m.id for m in models])
# Out:
# Models: ['9jalingo-tts-1']

# %%
speakers = client.tts.list_speakers(language="yo")
print(f"Yoruba speakers: {len(speakers)}")
# Out:
# Yoruba speakers: 59

# %%
speakers = client.tts.list_speakers(language="ig")
print(f"Igbo speakers: {len(speakers)}")
# Out:
# Igbo speakers: 66

# %%
speakers = client.tts.list_speakers(language="ha")
print(f"Hausa speakers: {len(speakers)}")
# Out:
# Hausa speakers: 44

# %%
speakers = client.tts.list_speakers(language="pcm")
print(f"Pidgin speakers: {len(speakers)}")
# Out:
# Pidgin speakers: 121

# %%
info = client.api_info()
print("API:", info.name, info.version)
# Out:
# API: 9jalingo TTS API 1.0.0

# %%
# Generate speech
audio = client.tts.generate("How you dey my son?", voice="ada_pcm", response_format="wav")
audio.save("files/pidgin_output.wav")
print(f"Generated {len(audio)} bytes")
# Out:
# Generated 69210 bytes

# %%
audio.media_type
# Out:
# 'audio/wav'

# %%
# Generate speech
audio = client.tts.generate("Nah, How you dey my brother, I dey feel you die?", voice="bola_pcm", response_format="flac")
audio.save("files/pidgin_output.flac")
print(f"Generated {len(audio)} bytes")
# Out:
# Generated 105576 bytes

# %%
# With a specific speaker voice
audio = client.tts.generate(
    "Nnoo, kedu ka i mere?",
    speaker="adaeze_ig",
)
audio.save("files/adaeze_greeting.mp3")
# Out:
# WindowsPath('files/adaeze_greeting.mp3')

# %%
# # Stream to a file
# with open("long_speech.wav", "wb") as f:
#     for chunk in client.tts.stream("Very long text here...", voice="pcm"):
#         f.write(chunk)

# Or collect the full stream
long_text="""
        Life na one kind journey wey nobody fit fully understand. From the day person open eye for this world, the journey don start. 
        Some people go say life na race, some go say na school, others go talk say na battle. But the truth be say life na mixture of many things together. E get sweet time, e get bitter time, e get time wey everything go dey move smooth like fresh engine, and e get time wey everywhere go just scatter like market wey rain beat.
        """
stream = client.tts.stream(long_text, lang="pcm", speaker="ada_pcm")
audio = stream.collect()
audio.save("files/long_speech.wav")
# Out:
# WindowsPath('files/long_speech.wav')

# %%
# !pip install openai

# %%
from pathlib import Path
from openai import OpenAI

client_openai = OpenAI(api_key="your-key")  # use any string for now
# speech_file_path = Path(__file__).parent / "speech.mp3"

with client_openai.audio.speech.with_streaming_response.create(
    model="gpt-4o-mini-tts",
    voice="coral",
    input=long_text,
    instructions="Speak in a cheerful and positive tone.",
) as response:
    response.stream_to_file("files/speech.mp3")

# %%
from pathlib import Path

cwd = Path.cwd()

# If you're inside src/, go up one level
if (cwd / "files").exists():
    BASE_DIR = cwd
else:
    BASE_DIR = cwd.parent

audio_path = BASE_DIR / "files" / "pastor.aac"

audio = client.tts.clone(
    " Love your neighbor as yourself, so that your days will be long, and your Father in Heaven will bless you.",
    audio_file=str(audio_path),
    voice="madman_pcm",
)

audio.save("cloned.wav")
cloned_voice_id = audio.voice_id
print(f"Cloned voice ID: {cloned_voice_id}")

# Reuse the cloned voice in a later request:
client.tts.generate("Hello again", voice=cloned_voice_id)
client.tts.generate("Hello again", speaker=cloned_voice_id)
# Out:
# Cloned voice ID: be9f526e-8d2f-448e-9180-fd5ae02bcb69
# AudioResponse(76266 bytes, audio/wav)

# %%
long_text="""
        Life na one kind journey wey nobody fit fully understand. From the day person open eye for this world, the journey don start. 
        Some people go say life na race, some go say na school, others go talk say na battle. But the truth be say life na mixture of many things together. E get sweet time, e get bitter time, e get time wey everything go dey move smooth like fresh engine, and e get time wey everywhere go just scatter like market wey rain beat.
        """
stream = client.tts.stream(long_text, lang="pcm", speaker="be9f526e-8d2f-448e-9180-fd5ae02bcb69")
audio = stream.collect()
audio.save("files/testing_new.wav")
# Out:
# WindowsPath('files/testing_new.wav')

# %%
# List all speakers
speakers = client.tts.list_speakers()
for s in speakers:
    print(f"{s.id} — {s.language} ({s.gender})")

# Filter by language
yoruba_speakers = client.tts.list_speakers(language="yo")

# Get a specific speaker
speaker = client.tts.get_speaker("ada_pcm")
print(speaker.name, speaker.language)
# Out:
# chuks_voice_pcm_ce89fccf — pcm (None)
# bashir_voice_ha_ce89fccf — ha (None)
# chuks_voice1_pcm_ce89fccf — pcm (None)
# pastor_voice_pcm_ce89fccf — pcm (None)
# chuks_voice2_pcm_ce89fccf — pcm (None)
# bashir_voice_ha_ce89fccf_b069 — ha (None)
# chuks_voice_3_pcm_ce89fccf — pcm (None)
# chuks_voice4_pcm_ce89fccf — pcm (None)
# bashir_voice_ha_ce89fccf_10f9 — ha (None)
# chuks_voice_pcm_ce89fccf_fdd1 — pcm (None)
# pastor_voice_pcm_ce89fccf_bae5 — pcm (None)
# bashir_voice_ha_ce89fccf_f233 — ha (None)
# bashir_voice_ha_ce89fccf_15a4 — ha (None)
# bashir_man_ha_ce89fccf — ha (None)
# pastor_voice_pcm_ce89fccf_61cc — pcm (None)
# chuks_voice_pcm_ce89fccf_6e68 — pcm (None)
# bashir_voice4_ha_ce89fccf — ha (None)
# chuks_voice1_pcm_ce89fccf_a9b2 — pcm (None)
# chuks_voice_pcm_ce89fccf_39f9 — pcm (None)
# bashir_voice_ha_ce89fccf_2ec4 — ha (None)
# bashir_voice_ha_ce89fccf_32a6 — ha (None)
# chuks_voice7_pcm_ce89fccf — pcm (None)
# pastor_voice3_pcm_ce89fccf — pcm (None)
# abdullahi_ha — ha (male)
# abimbola_yo — yo (female)
# abisoye_yo — yo (female)
# abubakar_ha — ha (male)
# ada_pcm — pcm (female)
# adaeze_ig — ig (female)
# adanna_ig — ig (female)
# adaora_ig — ig (female)
# adekunle_yo — yo (male)
# adeniyi_yo — yo (male)
# adeola_yo — yo (female)
# adetokunbo_yo — yo (male)
# adetola_yo — yo (female)
# adunni_yo — yo (female)
# afolake_yo — yo (female)
# aisha_ha — ha (female)
# aisha_pcm — pcm (female)
# aliyu_ha — ha (male)
# amarachi_ig — ig (female)
# awulika_ig — ig (female)
# ayomide_yo — yo (female)
# azubuike_ig — ig (male)
# babajide_yo — yo (male)
# babatunde_yo — yo (male)
# bello_ha — ha (male)
# bilkisu_ha — ha (female)
# bimpe_yo — yo (female)
# binta_ha — ha (female)
# blessing_pcm — pcm (female)
# bola_pcm — pcm (male)
# boluwatife_yo — yo (female)
# bose_pcm — pcm (female)
# bright_pcm — pcm (male)
# bunmi_pcm — pcm (female)
# busayo_yo — yo (female)
# charles_pcm — pcm (male)
# chiamaka_ig — ig (female)
# chibueze_ig — ig (male)
# chidimma_ig — ig (female)
# chidinma_ig — ig (None)
# chijioke_ig — ig (male)
# chika_ig — ig (female)
# chinedu_ig — ig (male)
# chinwe_ig — ig (female)
# chinyere_ig — ig (female)
# chioma_pcm — pcm (female)
# chisimdi_ig — ig (female)
# chizoba_ig — ig (female)
# christy_pcm — pcm (female)
# comfort_pcm — pcm (female)
# daniel_pcm — pcm (male)
# danladi_ha — ha (male)
# david_pcm — pcm (male)
# dayo_yo — yo (male)
# deborah_pcm — pcm (female)
# dora_pcm — pcm (female)
# edith_pcm — pcm (female)
# edwin_pcm — pcm (male)
# ekene_ig — ig (male)
# emeka_ig — ig (male)
# emmanuel_pcm — pcm (male)
# eniola_yo — yo (female)
# esther_pcm — pcm (female)
# evelyn_pcm — pcm (female)
# ezinne_ig — ig (female)
# faith_pcm — pcm (female)
# fatima_ha — ha (female)
# felix_pcm — pcm (male)
# femi_yo — yo (male)
# flora_pcm — pcm (female)
# folake_yo — yo (female)
# frank_pcm — pcm (male)
# funke_pcm — pcm (female)
# funmilayo_yo — yo (female)
# george_pcm — pcm (male)
# gift_pcm — pcm (female)
# ginika_ig — ig (female)
# gloria_pcm — pcm (female)
# grace_pcm — pcm (female)
# hadiza_ha — ha (female)
# halima_ha — ha (female)
# hamza_ha — ha (male)
# haruna_ha — ha (male)
# hassan_ha — ha (male)
# hauwa_ha — ha (female)
# helen_pcm — pcm (female)
# henry_pcm — pcm (male)
# hope_pcm — pcm (female)
# hussaina_ha — ha (female)
# ibrahim_ha — ha (male)
# ifeanyi_ig — ig (male)
# ifeanyichukwu_ig — ig (female)
# ifeoluwa_yo — yo (female)
# ifeoma_ig — ig (female)
# ifunanya_ig — ig (female)
# ify_pcm — pcm (female)
# ijeoma_ig — ig (female)
# ike_pcm — pcm (male)
# ikechukwu_ig — ig (male)
# isioma_ig — ig (female)
# ismail_ha — ha (male)
# iyabo_yo — yo (female)
# james_pcm — pcm (male)
# jamila_ha — ha (female)
# janet_pcm — pcm (female)
# jide_yo — yo (male)
# jidenna_ig — ig (male)
# joseph_pcm — pcm (male)
# joy_pcm — pcm (female)
# jumoke_yo — yo (female)
# kalatu_pcm — pcm (female)
# kehinde_yo — yo (male)
# kelechi_ig — ig (female)
# kemi_pcm — pcm (female)
# kenechukwu_ig — ig (male)
# kenneth_pcm — pcm (male)
# kofoworola_yo — yo (female)
# kunle_yo — yo (male)
# lawrence_pcm — pcm (male)
# linda_pcm — pcm (female)
# lola_pcm — pcm (female)
# lotachi_ig — ig (female)
# lucky_pcm — pcm (male)
# mabel_pcm — pcm (female)
# mahmud_ha — ha (male)
# mary_pcm — pcm (female)
# maryam_ha — ha (female)
# mercy_pcm — pcm (female)
# michael_pcm — pcm (male)
# mojisola_yo — yo (female)
# morenike_yo — yo (female)
# morenikeji_yo — yo (female)
# moses_pcm — pcm (male)
# munachi_ig — ig (female)
# mustapha_ha — ha (male)
# nafisa_ha — ha (female)
# ndubuisi_ig — ig (male)
# ngozi_ig — ig (female)
# nike_pcm — pcm (female)
# nkechi_ig — ig (female)
# nkeiru_ig — ig (female)
# nkem_pcm — pcm (male)
# nkemjika_ig — ig (female)
# nkiruka_ig — ig (female)
# nmesoma_ig — ig (female)
# nneamaka_ig — ig (female)
# nneka_ig — ig (female)
# nnenne_ig — ig (female)
# nneoma_ig — ig (female)
# nonso_pcm — pcm (male)
# nuhu_ha — ha (male)
# nwaka_ig — ig (female)
# nwamaka_ig — ig (female)
# obasi_pcm — pcm (male)
# obi_ig — ig (male)
# obiageli_ig — ig (female)
# obianuju_ig — ig (female)
# obinna_ig — ig (male)
# obiora_ig — ig (male)
# ogadinma_ig — ig (female)
# ogechi_ig — ig (female)
# ogechukwu_ig — ig (female)
# okechukwu_ig — ig (male)
# oladipo_yo — yo (male)
# olalekan_yo — yo (male)
# olatunde_yo — yo (male)
# olatunji_yo — yo (male)
# olayinka_yo — yo (female)
# ololade_yo — yo (female)
# olu_pcm — pcm (male)
# olufunke_yo — yo (female)
# oluomachi_ig — ig (female)
# olusegun_yo — yo (male)
# oluwafemi_yo — yo (male)
# oluwakemi_yo — yo (female)
# oluwaseyi_yo — yo (female)
# omolade_yo — yo (female)
# omolara_yo — yo (female)
# omowunmi_yo — yo (female)
# onyinye_ig — ig (female)
# opeyemi_yo — yo (female)
# ovie_pcm — pcm (female)
# oyindamola_yo — yo (female)
# patience_pcm — pcm (female)
# patrick_pcm — pcm (male)
# pauline_pcm — pcm (female)
# peace_pcm — pcm (female)
# peter_pcm — pcm (male)
# precious_pcm — pcm (female)
# queen_pcm — pcm (female)
# rabi_ha — ha (female)
# raymond_pcm — pcm (male)
# richard_pcm — pcm (male)
# ronke_yo — yo (female)
# rose_pcm — pcm (female)
# ruth_pcm — pcm (female)
# sade_yo — yo (female)
# sadiya_ha — ha (female)
# safiya_ha — ha (female)
# samuel_pcm — pcm (male)
# sanusi_ha — ha (male)
# sarah_pcm — pcm (female)
# segun_yo — yo (male)
# seun_pcm — pcm (male)
# shehu_ha — ha (male)
# simisola_yo — yo (female)
# somtochi_ig — ig (female)
# stella_pcm — pcm (female)
# sunday_pcm — pcm (male)
# taiwo_yo — yo (male)
# tanko_ha — ha (male)
# tayo_pcm — pcm (male)
# temi_pcm — pcm (female)
# temilade_yo — yo (female)
# temiloluwa_yo — yo (male)
# temitope_yo — yo (female)
# titilayo_yo — yo (female)
# tochukwu_ig — ig (male)
# tolulope_yo — yo (female)
# toyin_pcm — pcm (female)
# tunde_yo — yo (male)
# uchenna_ig — ig (female)
# ugochi_ig — ig (female)
# ugochukwu_ig — ig (male)
# uju_pcm — pcm (female)
# ujunwa_ig — ig (female)
# uloaku_ig — ig (female)
# uloma_ig — ig (female)
# usman_ha — ha (male)
# uzoamaka_ig — ig (female)
# victor_pcm — pcm (male)
# victoria_pcm — pcm (female)
# vivian_pcm — pcm (female)
# wale_yo — yo (male)
# wunmi_pcm — pcm (female)
# yeside_pcm — pcm (female)
# yetunde_yo — yo (female)
# yusuf_ha — ha (male)
# zainab_ha — ha (female)
# zainab_pcm — pcm (female)
# abigail_ochanya_pcm_ce89fccf — pcm (None)
# cloned_pcm_voice_pcm_ce89fccf — pcm (None)
# cloned_pcm_voice_pcm_ce89fccf_79fe — pcm (None)
# cloned_pcm_voice_pcm_ce89fccf_7f21 — pcm (None)
# cloned_pcm_voice_pcm_ce89fccf_efc2 — pcm (None)
# cloned_pcm_voice_pcm_ce89fccf_5f39 — pcm (None)
# cloned_pcm_voice_pcm_ce89fccf_2f3b — pcm (None)
# cloned_pcm_voice_pcm_ce89fccf_205d — pcm (None)
# cloned_pcm_voice_pcm_ce89fccf_a172 — pcm (None)
# cloned_pcm_voice_pcm_ce89fccf_2589 — pcm (None)
# clone_1f603400 — pcm (None)
# clone_6477ec41 — pcm (None)
# clone_61daf78c — pcm (None)
# clone_1844c4ab — pcm (None)
# clone_e7b3e14b — ha (None)
# clone_044d0f06 — ha (None)
# clone_214932ac — pcm (None)
# clone_6c4d97d6 — pcm (None)
# clone_4a30d1e6 — pcm (None)
# clone_5946773c — pcm (None)
# clone_55a8eac4 — pcm (None)
# clone_54628827 — pcm (None)
# clone_972a95fb — pcm (None)
# clone_6cdcbf64 — pcm (None)
# clone_c76e5c75 — pcm (None)
# clone_85adc5f0 — pcm (None)
# clone_b58aaa23 — pcm (None)
# clone_e22da9c0 — pcm (None)
# clone_907934fc — pcm (None)
# Ada pcm

# %%
# Get root API information
info = client.api_info()
print(info.name)        # "9jaLingo TTS API"
print(info.version)     # "1.0.0"
print(info.endpoints)   # dict of all available endpoints

# Get v1 service metadata
service = client.service_info()
print(service.name)             # "9jaLingo API v1"
print(service.speech_url)       # "/v1/audio/speech"
print(service.models_url)       # "/v1/models"
# Out:
# 9jalingo TTS API
# 1.0.0
# {'/v1/audio/speech': 'POST — Generate speech (OpenAI-compatible)', '/v1/audio/speech/stream': 'POST — Stream speech generation (chunked transfer)', '/v1/audio/clone': 'POST — Voice cloning from uploaded audio', '/v1/models': 'GET  — Public model aliases', '/v1/speakers': 'GET  — List available speakers', '/v1/speakers/{id}': 'GET  — Single speaker info', '/v1/languages': 'GET  — List supported languages', '/v1/health': 'GET  — Health check'}
# 9jalingo API v1
# /v1/audio/speech
# /v1/models

# %%
client.tts.delete_voice(cloned_voice_id)
